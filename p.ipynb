# %%
import networkx as nx
from collections import OrderedDict
import matplotlib.pyplot as plt
#global str
DG=nx.DiGraph()
#DG.add_path([0,1,2,3])

file=open('input1.txt','r')
for x , N1 in enumerate(file):
    if x ==2:
        print(N1)
        DG.add_node(N1)
        
file=open('input2.txt','r')
for x , N2 in enumerate(file):
    if x ==2:
        print(N2)
        DG.add_node(N2)

file=open('input3.txt','r')
for x , N3 in enumerate(file):
    if x ==2:
        print(N3)
        DG.add_node(N3)

file=open('input4.txt','r')
for x , N4 in enumerate(file):
    if x ==2:
        print(N4)
        DG.add_node(N4)

DG.add_edges_from([("N1","N2"),("N1","N3"),("N1","N4"),("N2","N3"),("N2","N4"),("N3","N4")])
#DG.add_edge(input2,input3)
#G.add_edges_from([("a","c"),("c","d"), ("a",1), (1,"d"), ("a",2)])

in_degree=list(DG.in_degree())
a=dict(in_degree)
print(in_degree)

print("\n\n")
#degree_sequence = sorted([d for n, d in DG.in_degree()], reverse=False)
degree_sequence = OrderedDict(sorted(a.items(), key=lambda x: x[1]))

for k, v in degree_sequence.items():
    print("%s: %s" % (k, v))

print("\n\n")
for k, v in degree_sequence.items():
   
    m=str(k)
    if m=="N1":
        file=open('input1.txt','r')
        for x , N1 in enumerate(file):
            print(N1)
    if m=='N2':
        file=open('input2.txt','r')
        for x , N2 in enumerate(file):
            print(N2)
        
    if m=='N3':
        file=open('input3.txt','r')
        for x , N3 in enumerate(file):
            print(N3)
    if m=='N4':
        file=open('input4.txt','r')
        for x , N4 in enumerate(file):
            print(N4)
    else:
        print(" ")
pos = nx.spring_layout(DG)
nx.draw(DG,pos,node_color='r',node_size=500,alpha=1)
plt.show()
# Out:
# w(y)
#
# w(y)
#
# w(y)
#
# w(y)
#
# [('w(y)\n', 0), ('N1', 0), ('N2', 1), ('N3', 2), ('N4', 3)]
#
#
#
# w(y)
# : 0
# N1: 0
# N2: 1
# N3: 2
# N4: 3
#
#
#
#
# N1;
#
# r1(Y)
#
# w(y)
#
# r1(y)
#
#
#
#
# N2;
#
# r1(Y)
#
# w(y)
#
# r1(y)
#
#
#
#
# N3;
#
# r1(Y)
#
# w(y)
#
# r1(y)
#
#
#
#
# N4;
#
# r1(Y)
#
# w(y)
#
# r1(y)

# %%
import random
import networkx as nx
from collections import OrderedDict

#global str
DG=nx.DiGraph()
edges=[]
def transaction1():
    with open("input1.txt") as fobj:
    text = fobj.read().strip().split()
    for N1 in file:
        if N1 == "w1(Y)":
            print(N1)
            DG.add_node("N1")
            edges.append("N1")
            #print()   
def transaction2():
    file=open('input2.txt','r')
    for N2 in file:
         if N2 == "w1(Y)":
            print(N2)
            DG.add_node("N2")
            edges.append("N2")
def transaction3():
    file=open('input3.txt','r')
    for N3 in file:
         if N3 == "w1(Y)":
            print(N3)
            DG.add_node("N3")
            edges.append("N3")
def transaction4():
    file=open('input4.txt','r')
    for N4 in file:
         if N4 == "w1(Y)":
            print(N4)
            DG.add_node("N4")
            edges.append("N4")
    # Get the function from switcher dictionary

#key=int(input("Enter the key value"))
#value=input("Enter the value")

#switcher[key]=value
switcher={
    0:transaction1,
    1:transaction2,
    2:transaction3,
    3:transaction4,
}

number=int(input("enter the number of transaction"))
keyname=[0,1,2,3]
for i in range(number):
    n=int(input("enter the transaction which you want to execute"))
    switcher[keyname[n]]()
    
#print("print the list",edges)

print(edges)

#DG.add_edges_from([("N1","N2"),("N1","N3"),("N1","N4"),("N2","N3"),("N2","N4"),("N3","N4")])
DG.add_edges_from([(edges[0],edges[1]),(edges[0],edges[2]),(edges[0],edges[3]),(edges[1],edges[2]),(edges[1],edges[3]),(edges[2],edges[3])])
#DG.add_edge(input2,input3)
#G.add_edges_from([("a","c"),("c","d"), ("a",1), (1,"d"), ("a",2)])

in_degree=list(DG.in_degree())
#print(in_degree) 

print("\n")
#degree_sequence = sorted([d for n, d in DG.in_degree()], reverse=False)
degree_sequence = OrderedDict(sorted(in_degree, key=lambda x: x[1]))
for k, v in degree_sequence.items():
        print(k,v)

print("\n\n")
for k, v in degree_sequence.items():
   
    m=str(k)
    if m=="N1":
        file=open('input1.txt','r')
        for x , N1 in enumerate(file):
            print(N1)
    if m=='N2':
        file=open('input2.txt','r')
        for x , N2 in enumerate(file):
            print(N2)
        
    if m=='N3':
        file=open('input3.txt','r')
        for x , N3 in enumerate(file):
            print(N3)
    if m=='N4':
        file=open('input4.txt','r')
        for x , N4 in enumerate(file):
            print(N4)
    else:
        print(" ")
pos = nx.spring_layout(DG)
nx.draw(DG,pos,node_color='r',node_size=500,alpha=1)
plt.show()
# Out:
# enter the number of transaction4
# enter the transaction which you want to execute0
# enter the transaction which you want to execute1
# enter the transaction which you want to execute2
# enter the transaction which you want to execute3
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-a95a885fb856> in <module>()
#      59
#      60 #DG.add_edges_from([("N1","N2"),("N1","N3"),("N1","N4"),("N2","N3"),("N2","N4"),("N3","N4")])
# ---> 61 DG.add_edges_from([(edges[0],edges[1]),(edges[0],edges[2]),(edges[0],edges[3]),(edges[1],edges[2]),(edges[1],edges[3]),(edges[2],edges[3])])
#      62 #DG.add_edge(input2,input3)
#      63 #G.add_edges_from([("a","c"),("c","d"), ("a",1), (1,"d"), ("a",2)])
#
# IndexError: list index out of range

# %%
import random
import networkx as nx
from collections import OrderedDict

#global str
DG=nx.DiGraph()
edges=[]
def transaction1():
    file=open('input1.txt','r')
    for x , N1 in enumerate(file):
        if x ==5:
            print(N1)
            DG.add_node("N1")
            edges.append("N1")
            #print()   
def transaction2():
    file=open('input2.txt','r')
    for x , N2 in enumerate(file):
        if x ==2:
            print(N2)
            DG.add_node("N2")
            edges.append("N2")
def transaction3():
    file=open('input3.txt','r')
    for x , N3 in enumerate(file):
        if x ==5:
            print(N3)
            DG.add_node("N3")
            edges.append("N3")
def transaction4():
    file=open('input4.txt','r')
    for x , N4 in enumerate(file):
        if x ==5:
            print(N4)
            DG.add_node("N4")
            edges.append("N4")
    # Get the function from switcher dictionary

#key=int(input("Enter the key value"))
#value=input("Enter the value")

#switcher[key]=value
switcher={
    0:transaction1,
    1:transaction2,
    2:transaction3,
    3:transaction4,
}

number=int(input("enter the number of transaction"))
keyname=[0,1,2,3]
for i in range(number):
    n=int(input("enter the transaction which you want to execute"))
    switcher[keyname[n]]()
    
#print("print the list",edges)

print(edges)

#DG.add_edges_from([("N1","N2"),("N1","N3"),("N1","N4"),("N2","N3"),("N2","N4"),("N3","N4")])
#DG.add_edges_from([(edges[0],edges[1]),(edges[0],edges[2]),(edges[0],edges[3]),(edges[1],edges[2]),(edges[1],edges[3]),(edges[2],edges[3])])
#DG.add_edge(input2,input3)
#G.add_edges_from([("a","c"),("c","d"), ("a",1), (1,"d"), ("a",2)])

in_degree=list(DG.in_degree())
#print(in_degree) 

print("\n")
#degree_sequence = sorted([d for n, d in DG.in_degree()], reverse=False)
degree_sequence = OrderedDict(sorted(in_degree, key=lambda x: x[1]))
for k, v in degree_sequence.items():
        print(k,v)

print("\n\n")
for k, v in degree_sequence.items():
   
    m=str(k)
    if m=="N1":
        file=open('input1.txt','r')
        for x , N1 in enumerate(file):
            print(N1)
    if m=='N2':
        file=open('input2.txt','r')
        for x , N2 in enumerate(file):
            print(N2)
        
    if m=='N3':
        file=open('input3.txt','r')
        for x , N3 in enumerate(file):
            print(N3)
    if m=='N4':
        file=open('input4.txt','r')
        for x , N4 in enumerate(file):
            print(N4)
    else:
        print(" ")
pos = nx.spring_layout(DG)
nx.draw(DG,pos,node_color='r',node_size=500,alpha=1)
plt.show()
# Out:
# enter the number of transaction4
# enter the transaction which you want to execute0
# enter the transaction which you want to execute3
# enter the transaction which you want to execute2
# enter the transaction which you want to execute1
# w1 (Y);
#
# ['N2']
#
#
# N2 0
#
#
#
# N2;
#
# r1 (Y);
#
# w1 (Y);
#
# r1 (y);

# %%
import random
import networkx as nx
from collections import OrderedDict

#global str
DG=nx.DiGraph()
edges=[]
def transaction1():
    file=open('input1.txt','r')
    for x , N1 in enumerate(file):
        if x ==2:
            print(N1)
            DG.add_node("N1")
            edges.append("N1")
            #print()   
def transaction2():
    file=open('input2.txt','r')
    for x , N2 in enumerate(file):
        if x ==2:
            print(N2)
            DG.add_node("N2")
            edges.append("N2")
def transaction3():
    file=open('input3.txt','r')
    for x , N3 in enumerate(file):
        if x ==2:
            print(N3)
            DG.add_node("N3")
            edges.append("N3")
def transaction4():
    file=open('input4.txt','r')
    for x , N4 in enumerate(file):
        if x ==2:
            print(N4)
            DG.add_node("N4")
            edges.append("N4")
    # Get the function from switcher dictionary

#key=int(input("Enter the key value"))
#value=input("Enter the value")

#switcher[key]=value
switcher={
    0:transaction1,
    1:transaction2,
    2:transaction3,
    3:transaction4,
}

number=int(input("enter the number of transaction"))
keyname=[0,1,2,3]
for i in range(number):
    n=int(input("enter the transaction which you want to execute"))
    switcher[keyname[n]]()
    
#print("print the list",edges)

print(edges)

#DG.add_edges_from([("N1","N2"),("N1","N3"),("N1","N4"),("N2","N3"),("N2","N4"),("N3","N4")])
DG.add_edges_from([(edges[0],edges[1]),(edges[0],edges[2]),(edges[0],edges[3]),(edges[1],edges[2]),(edges[1],edges[3]),(edges[2],edges[3])])
#DG.add_edge(input2,input3)
#G.add_edges_from([("a","c"),("c","d"), ("a",1), (1,"d"), ("a",2)])

in_degree=list(DG.in_degree())
#print(in_degree) 

print("\n")
#degree_sequence = sorted([d for n, d in DG.in_degree()], reverse=False)
degree_sequence = OrderedDict(sorted(in_degree, key=lambda x: x[1]))
for k, v in degree_sequence.items():
        print(k,v)

print("\n\n")
for k, v in degree_sequence.items():
   
    m=str(k)
    if m=="N1":
        file=open('input1.txt','r')
        for x , N1 in enumerate(file):
            print(N1)
    if m=='N2':
        file=open('input2.txt','r')
        for x , N2 in enumerate(file):
            print(N2)
        
    if m=='N3':
        file=open('input3.txt','r')
        for x , N3 in enumerate(file):
            print(N3)
    if m=='N4':
        file=open('input4.txt','r')
        for x , N4 in enumerate(file):
            print(N4)
    else:
        print(" ")
pos = nx.spring_layout(DG)
nx.draw(DG,pos,node_color='r',node_size=500,alpha=1)
plt.show()
# Out:
# enter the number of transaction4
# enter the transaction which you want to execute0
# w1(Y);
#
# enter the transaction which you want to execute2
# w1 (Y);
#
# enter the transaction which you want to execute3
# w1 (Y);
#
# enter the transaction which you want to execute1
# w1 (Y);
#
# ['N1', 'N3', 'N4', 'N2']
#
#
# N1 0
# N3 1
# N4 2
# N2 3
#
#
#
# N1;
#
# r1(Y);
#
# w1(Y);
#
# r1(y);
#
#
#
#
# N3;
#
# r1 (Y);
#
# w1 (Y);
#
# r1 (y);
#
#
# N4;
#
# r1 (Y);
#
# w1 (Y);
#
# r1 (y);
#
# N2;
#
# r1 (Y);
#
# w1 (Y);
#
# r1 (y);

# %%
file=open('input1.txt','r')
for x , N1 in enumerate(file):
            str1=N1
            l1=str1.find("w1(Y);")
            
            print(l1)
            DG.add_node("N1")
            edges.append("N1")
# Out:
# -1
# -1
# 0
# -1
# -1

# %%
import matplotlib.pyplot as plt
import networkx as nx
class Graph:
    def __init__(self):
        # dictionary containing keys that map to the corresponding vertex object
        self.vertices = {}
 
    def add_vertex(self, key):
       
        vertex = Vertex(key)
        self.vertices[key] = vertex
 
    def get_vertex(self, key):
       
        return self.vertices[key]
 
    def __contains__(self, key):
        return key in self.vertices
 
    def add_edge(self, src_key, dest_key, weight=1):
       
        self.vertices[src_key].add_neighbour(self.vertices[dest_key], weight)
 
    def does_edge_exist(self, src_key, dest_key):
      
        return self.vertices[src_key].does_it_point_to(self.vertices[dest_key])
 
    def __iter__(self):
        return iter(self.vertices.values())
 
 
class Vertex:
    def __init__(self, key):
        self.key = key
        self.points_to = {}
 
    def get_key(self):
       
        return self.key
 
    def add_neighbour(self, dest, weight):
        
        self.points_to[dest] = weight
 
    def get_neighbours(self):
       
        return self.points_to.keys()
 
    def get_weight(self, dest):
       
        return self.points_to[dest]
 
    def does_it_point_to(self, dest):
        """Return True if this vertex points to dest."""
        return dest in self.points_to
 
 
def is_cycle_present(graph):
   
    on_stack = set()
    visited = set()
    for v in graph:
        if v not in visited:
            if is_cycle_present_helper(v, visited, on_stack):
                return True
    return False
 
def is_cycle_present_helper(v, visited, on_stack):
    
    if v in on_stack:
        return True
    on_stack.add(v)
    for dest in v.get_neighbours():
        if dest not in visited:
            if is_cycle_present_helper(dest, visited, on_stack):
                return True
    on_stack.remove(v)
    visited.add(v)
    return False
 
g =Graph()
print('Menu')
print('add vertex <key>')
print('add edge <vertex1> <vertex2>')
print('cycle')
print('display')
print('quit')
 
while True:
    do = input('What would you like to do? ').split()
 
    operation = do[0]
    if operation == 'add':
        suboperation = do[1]
        if suboperation == 'vertex':
            key = int(do[2])
            if key not in g:
                g.add_vertex(key)
            else:
                print('Vertex already exists.')
        elif suboperation == 'edge':
            v1 = int(do[2])
            v2 = int(do[3])
            if v1 not in g:
                print('Vertex {} does not exist.'.format(v1))
            elif v2 not in g:
                print('Vertex {} does not exist.'.format(v2))
            else:
                if not g.does_edge_exist(v1, v2):
                    g.add_edge(v1, v2)
                else:
                    print('Edge already exists.')
 
    elif operation == 'cycle':
        if is_cycle_present(g):
            print('Cycle present.')
        else:
            print('Cycle not present.')
 
    elif operation == 'display':
        print('Vertices: ', end='')
        for v in g:
            print(v.get_key(), end=' ')
        print()
 
        print('Edges:')
        for v in g:
            for dest in v.get_neighbours():
                w = v.get_weight(dest)
                print('(src={}, dest={}, weight={}) '.format(v.get_key(),
                                                             dest.get_key(), w))
        print()
 
    elif operation == 'quit':
        #pos = nx.spring_layout(g)
        #nx.draw(g,pos,node_color='r',node_size=500,alpha=1)
        #plt.show()

        in_degree=list(g.in_degree())
        print(in_degree) 

print("\n")
#degree_sequence = sorted([d for n, d in DG.in_degree()], reverse=False)
        #degree_sequence = OrderedDict(sorted(in_degree, key=lambda x: x[1]))
        #for k, v in degree_sequence.items():
            #print(k,v)

#print("\n\n")
# Out:
# Menu
# add vertex <key>
# add edge <vertex1> <vertex2>
# cycle
# display
# quit
# What would you like to do? add vertex 1
# What would you like to do? add vertex 2
# What would you like to do? add vertex 3
# What would you like to do? add vertex 4
# What would you like to do? add edge 1 2
# What would you like to do? add edge 2 3
# What would you like to do? add edge 3 4
# What would you like to do? add edge 4 1
# What would you like to do? cycle
# Cycle present.
# What would you like to do? display
# Vertices: 1 2 3 4
# Edges:
# (src=1, dest=2, weight=1)
# (src=2, dest=3, weight=1)
# (src=3, dest=4, weight=1)
# (src=4, dest=1, weight=1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /anaconda3/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /anaconda3/anaconda3/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     795         try:
# --> 796             msg_list = socket.recv_multipart(mode, copy=copy)
#     797         except zmq.ZMQError as e:
#
# /anaconda3/anaconda3/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7683)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7460)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq/backend/cython/socket.c:2344)()
#
# /anaconda3/anaconda3/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:9621)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-819bef68e095> in <module>()
#      88
#      89 while True:
# ---> 90     do = input('What would you like to do? ').split()
#      91
#      92     operation = do[0]
#
# /anaconda3/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /anaconda3/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %%
import random
import networkx as nx
from collections import OrderedDict
import matplotlib.pyplot as plt
#global str
DG=nx.DiGraph()
edges=[]
def transaction1():
    file=open('input1.txt','r')
    for x , N1 in enumerate(file):
        if x ==2:
            print(N1)
            DG.add_node("N1")
            edges.append("N1")
            #print()   
def transaction2():
    file=open('input2.txt','r')
    for x , N2 in enumerate(file):
        if x ==2:
            print(N2)
            DG.add_node("N2")
            edges.append("N2")
def transaction3():
    file=open('input3.txt','r')
    for x , N3 in enumerate(file):
        if x ==2:
            print(N3)
            DG.add_node("N3")
            edges.append("N3")
def transaction4():
    file=open('input4.txt','r')
    for x , N4 in enumerate(file):
        if x ==2:
            print(N4)
            DG.add_node("N4")
            edges.append("N4")
    # Get the function from switcher dictionary

#key=int(input("Enter the key value"))
#value=input("Enter the value")

#switcher[key]=value
switcher={
    0:transaction1,
    1:transaction2,
    2:transaction3,
    3:transaction4,
}

number=int(input("enter the number of transaction"))
keyname=[0,1,2,3]
for i in range(number):
    n=int(input("enter the transaction which you want to execute"))
    switcher[keyname[n]]()
    
#print("print the list",edges)

print(edges)

#DG.add_edges_from([("N1","N2"),("N1","N3"),("N1","N4"),("N2","N3"),("N2","N4"),("N3","N4")])
DG.add_edges_from([(edges[0],edges[1]),(edges[1],edges[0]),(edges[0],edges[3]),(edges[1],edges[2]),(edges[1],edges[3]),(edges[2],edges[3])])
#DG.add_edge(input2,input3)
#G.add_edges_from([("a","c"),("c","d"), ("a",1), (1,"d"), ("a",2)])

in_degree=list(DG.in_degree())
#print(in_degree) 

print("\n")
#degree_sequence = sorted([d for n, d in DG.in_degree()], reverse=False)
degree_sequence = OrderedDict(sorted(in_degree, key=lambda x: x[1]))
for k, v in degree_sequence.items():
        print(k,v)

print("\n\n")
def is_cycle_present(graph):
   
    on_stack = set()
    visited = set()
    for v in graph:
        if v not in visited:
            if is_cycle_present_helper(v, visited, on_stack):
                return True
    return False
 
def is_cycle_present_helper(v, visited, on_stack):
    
    if v in on_stack:
        return True
    on_stack.add(v)
    for dest in v.get_neighbours():
        if dest not in visited:
            if is_cycle_present_helper(dest, visited, on_stack):
                return True
    on_stack.remove(v)
    visited.add(v)
    return False

if is_cycle_present(DG):
    print('Cycle present.')
else:
    print('Cycle not present.')

pos = nx.spring_layout(DG)
nx.draw(DG,pos,node_color='r',node_size=500,alpha=1)
plt.show()
# Out:
# enter the number of transaction4
# enter the transaction which you want to execute3
# w1 (Y);
#
# enter the transaction which you want to execute2
# w1 (Y);
#
# enter the transaction which you want to execute1
# w1 (Y);
#
# enter the transaction which you want to execute0
# w1(Y);
#
# ['N4', 'N3', 'N2', 'N1']
#
#
# N4 1
# N3 1
# N2 1
# N1 3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-63a41a570e51> in <module>()
#      96     return False
#      97
# ---> 98 if is_cycle_present(DG):
#      99     print('Cycle present.')
#     100 else:
#
# <ipython-input-13-63a41a570e51> in is_cycle_present(graph)
#      79     for v in graph:
#      80         if v not in visited:
# ---> 81             if is_cycle_present_helper(v, visited, on_stack):
#      82                 return True
#      83     return False
#
# <ipython-input-13-63a41a570e51> in is_cycle_present_helper(v, visited, on_stack)
#      88         return True
#      89     on_stack.add(v)
# ---> 90     for dest in v.get_neighbours():
#      91         if dest not in visited:
#      92             if is_cycle_present_helper(dest, visited, on_stack):
#
# AttributeError: 'str' object has no attribute 'get_neighbours'

# %%
from collections import defaultdict 

class Graph(): 
	def __init__(self,vertices): 
		self.graph = defaultdict(list) 
		self.V = vertices 

	def addEdge(self,u,v): 
		self.graph[u].append(v) 

	def isCyclicUtil(self, v, visited, recStack): 

		# Mark current node as visited and 
		# adds to recursion stack 
		visited[v] = True
		recStack[v] = True

		# Recur for all neighbours 
		# if any neighbour is visited and in 
		# recStack then graph is cyclic 
		for neighbour in self.graph[v]: 
			if visited[neighbour] == False: 
				if self.isCyclicUtil(neighbour, visited, recStack) == True: 
					return True
			elif recStack[neighbour] == True: 
				return True

		# The node needs to be poped from 
		# recursion stack before function ends 
		recStack[v] = False
		return False

	# Returns true if graph is cyclic else false 
	def isCyclic(self): 
		visited = [False] * self.V 
		recStack = [False] * self.V 
		for node in range(self.V): 
			if visited[node] == False: 
				if self.isCyclicUtil(node,visited,recStack) == True: 
                    print (node,visited,recStack)
					return True
		return False

g = Graph(4) 
g.addEdge(0, 1) 
g.addEdge(0, 2) 
g.addEdge(1, 2) 
g.addEdge(2, 0) 
g.addEdge(2, 3) 
g.addEdge(3, 3) 
if g.isCyclic() == 1: 
	print ("Graph has a cycle")
else: 
	print ("Graph has no cycle")
# Out:
#   File "<tokenize>", line 40
#     print (node,visited,recStack)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
from graph_tool.all import *
g = Graph()
ug = Graph(directed=False)
v1 = g.add_vertex()
v2 = g.add_vertex()
e = g.add_edge(v1, v2)

graph_draw(g, vertex_text=g.vertex_index, vertex_font_size=18,output_size=(200, 200), output="two-nodes.png")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-891fac2da3d5> in <module>()
# ----> 1 from graph_tool.all import *
#       2 g = Graph()
#       3 ug = Graph(directed=False)
#       4 v1 = g.add_vertex()
#       5 v2 = g.add_vertex()
#
# ModuleNotFoundError: No module named 'graph_tool'

# %%
import matplotlib.pyplot as plt
import networkx as nx
class Graph:
    def __init__(self):
        # dictionary containing keys that map to the corresponding vertex object
        self.vertices = {}
 
    def add_vertex(self, key):
       
        vertex = Vertex(key)
        self.vertices[key] = vertex
 
    def get_vertex(self, key):
       
        return self.vertices[key]
 
    def __contains__(self, key):
        return key in self.vertices
 
    def add_edge(self, src_key, dest_key, weight=1):
       
        self.vertices[src_key].add_neighbour(self.vertices[dest_key], weight)
 
    def does_edge_exist(self, src_key, dest_key):
      
        return self.vertices[src_key].does_it_point_to(self.vertices[dest_key])
 
    def __iter__(self):
        return iter(self.vertices.values())
 
 
class Vertex:
    def transaction1():
    file=open('input1.txt','r')
    for x , N1 in enumerate(file):
        if x ==2:
            print(N1)
            DG.add_node("N1")
            edges.append("N1")
            #print()   
    def transaction2():
    file=open('input2.txt','r')
    for x , N2 in enumerate(file):
        if x ==2:
            print(N2)
            DG.add_node("N2")
            edges.append("N2")
    def transaction3():
    file=open('input3.txt','r')
    for x , N3 in enumerate(file):
        if x ==2:
            print(N3)
            DG.add_node("N3")
            edges.append("N3")
def transaction4():
    file=open('input4.txt','r')
    for x , N4 in enumerate(file):
        if x ==2:
            print(N4)
            DG.add_node("N4")
            edges.append("N4")
 
def is_cycle_present(graph):
   
    on_stack = set()
    visited = set()
    for v in graph:
        if v not in visited:
            if is_cycle_present_helper(v, visited, on_stack):
                return True
    return False
 
def is_cycle_present_helper(v, visited, on_stack):
    
    if v in on_stack:
        return True
    on_stack.add(v)
    for dest in v.get_neighbours():
        if dest not in visited:
            if is_cycle_present_helper(dest, visited, on_stack):
                return True
    on_stack.remove(v)
    visited.add(v)
    return False
 
g =Graph()
print('Menu')
print('add vertex <key>')
print('add edge <vertex1> <vertex2>')
print('cycle')
print('display')
print('quit')
 
while True:
    do = input('What would you like to do? ').split()
 
    operation = do[0]
    if operation == 'add':
        suboperation = do[1]
        if suboperation == 'vertex':
            key = int(do[2])
            if key not in g:
                g.add_vertex(key)
            else:
                print('Vertex already exists.')
        elif suboperation == 'edge':
            v1 = int(do[2])
            v2 = int(do[3])
            if v1 not in g:
                print('Vertex {} does not exist.'.format(v1))
            elif v2 not in g:
                print('Vertex {} does not exist.'.format(v2))
            else:
                if not g.does_edge_exist(v1, v2):
                    g.add_edge(v1, v2)
                else:
                    print('Edge already exists.')
 
    elif operation == 'cycle':
        if is_cycle_present(g):
            print('Cycle present.')
        else:
            print('Cycle not present.')
 
    elif operation == 'display':
        print('Vertices: ', end='')
        for v in g:
            print(v.get_key(), end=' ')
        print()
 
        print('Edges:')
        for v in g:
            for dest in v.get_neighbours():
                w = v.get_weight(dest)
                print('(src={}, dest={}, weight={}) '.format(v.get_key(),
                                                             dest.get_key(), w))
        print()
 
    elif operation == 'quit':
        #pos = nx.spring_layout(g)
        #nx.draw(g,pos,node_color='r',node_size=500,alpha=1)
        #plt.show()

        in_degree=list(g.in_degree())
        print(in_degree) 

print("\n")
#degree_sequence = sorted([d for n, d in DG.in_degree()], reverse=False)
        #degree_sequence = OrderedDict(sorted(in_degree, key=lambda x: x[1]))
        #for k, v in degree_sequence.items():
            #print(k,v)

#print("\n\n")

# %%
import random
import networkx as nx
from collections import OrderedDict

#global str
DG=nx.DiGraph()
edges=[]
def transaction1():
    file=open('input1.txt','r')
    for N1 in file:
        #if N1 == "w1(Y)":
            print(N1)
            DG.add_node("N1")
            edges.append("N1")
            #print()   
def transaction2():
    file=open('input2.txt','r')
    for N2 in file:
         #if N2 == "w1(Y)":
            print(N2)
            DG.add_node("N2")
            edges.append("N2")
def transaction3():
    file=open('input3.txt','r')
    for N3 in file:
        str(N3)
        if N3 == "w1(Y)":
            print(N3)
            DG.add_node("N3")
            edges.append("N3")
def transaction4():
    file=open('input4.txt','r')
    for N4 in file:
        
        if str(N4) =="w1(Y)":
            print(N4)
            DG.add_node("N4")
            edges.append("N4")
            
switcher={
    0:transaction1,
    1:transaction2,
    2:transaction3,
    3:transaction4,
}

number=int(input("enter the number of transaction"))
keyname=[0,1,2,3]
for i in range(number):
    n=int(input("enter the transaction which you want to execute"))
    switcher[keyname[n]]()
# Out:
# enter the number of transaction4
# enter the transaction which you want to execute3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /anaconda3/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /anaconda3/anaconda3/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     795         try:
# --> 796             msg_list = socket.recv_multipart(mode, copy=copy)
#     797         except zmq.ZMQError as e:
#
# /anaconda3/anaconda3/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7683)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7460)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq/backend/cython/socket.c:2344)()
#
# /anaconda3/anaconda3/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:9621)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-82903f2fa9e0> in <module>()
#      48 keyname=[0,1,2,3]
#      49 for i in range(number):
# ---> 50     n=int(input("enter the transaction which you want to execute"))
#      51     switcher[keyname[n]]()
#
# /anaconda3/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /anaconda3/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %%
list1=[]
file=open('input4.txt','r')
for N4 in file:
    #print(N4)
    list1.append(N4)
    #DG.add_node("N4")
    #edges.append("N4")

#print(list1)

for x , N1 in enumerate(list1):
    if str(N1)=="w1(Y)":
        print(N1)

# %%
with open('input4.txt', 'r') as myfile:
    data = myfile.readlines()
    for N4 in data:
        if N4 in "w1(y)":
            print("w1(y)")

# %%
with open("input1.txt") as fobj:
    text = fobj.read().strip().split()
    while True:
        try:
            s = "w(y)"
            if s == "":
                continue
            if s in text:
                print(s)
                break
            raise Exception("No such string found, try again")
        except Exception as e:
            print(e)

# %%
import random
import networkx as nx
import matplotlib.pyplot as plt
from collections import OrderedDict

#global str
DG=nx.DiGraph()
edges=[]
s = "w(y)"
def transaction1():
    with open("input1.txt") as fobj:
        text = fobj.read().strip().split()
        while True:
            try:
                #s = "w(y)"
                if s == "":
                    continue
                if s in text:
                    print(s)
                    DG.add_node("N1")
                    edges.append("N1")
                    break
                raise Exception("No such string found, try again")
            except Exception as e:
                print(e)
def transaction2():
    
    with open("input2.txt") as fobj:
        text = fobj.read().strip().split()
        while True:
            try:
                #s = "w(y)"
                if s == "":
                    continue
                if s in text:
                    print(s)
                    DG.add_node("N2")
                    edges.append("N2")
                    break
                raise Exception("No such string found, try again")
            except Exception as e:
                print(e)
def transaction3():
     with open("input3.txt") as fobj:
        text = fobj.read().strip().split()
        while True:
            try:
                #s = "w(y)"
                if s == "":
                    continue
                if s in text:
                    print(s)
                    DG.add_node("N3")
                    edges.append("N3")
                    break
                raise Exception("No such string found, try again")
            except Exception as e:
                print(e)
def transaction4():
     with open("input4.txt") as fobj:
        text = fobj.read().strip().split()
        while True:
            try:
               # s = "w(y)"
                if s == "":
                    continue
                if s in text:
                    print(s)
                    DG.add_node("N4")
                    edges.append("N4")
                    break
                raise Exception("No such string found, try again")
            except Exception as e:
                print(e)
    # Get the function from switcher dictionary

#key=int(input("Enter the key value"))
#value=input("Enter the value")

#switcher[key]=value
switcher={
    0:transaction1,
    1:transaction2,
    2:transaction3,
    3:transaction4,
}
while True:
    
    input1=input("would you like to continue y/n")
    if input1=="n":
        break;
    else:
        
        number=int(input("enter the number of transaction"))
        keyname=[0,1,2,3]
        for i in range(number):
            n=int(input("enter the transaction which you want to execute"))
            switcher[keyname[n]]()
    
#print("print the list",edges)

        print(edges)


        DG.add_edges_from([("N1","N2"),("N1","N3"),("N1","N4"),("N2","N3"),("N2","N4"),("N3","N4")])
        """if n==4: 
            DG.add_edges_from([(edges[0],edges[1]),(edges[0],edges[2]),(edges[0],edges[3]),(edges[1],edges[2]),(edges[1],edges[3]),(edges[2],edges[3])])
     
        elif n==1:
            DG.add_edges_from([edges[0]])
        
        elif n==2:
             DG.add_edges_from([edges[0]],edges[1])
        elif n==3:
             DG.add_edges_from([(edges[0])])
        """
        #DG.add_edge(input2,input3)
        #G.add_edges_from([("a","c"),("c","d"), ("a",1), (1,"d"), ("a",2)])

        in_degree=list(DG.in_degree())
        #print(in_degree) 

        print("\n")
        #degree_sequence = sorted([d for n, d in DG.in_degree()], reverse=False)
        degree_sequence = OrderedDict(sorted(in_degree, key=lambda x: x[1]))
        for k, v in degree_sequence.items():
                print(k,v)

        print("\n\n")
        for k, v in degree_sequence.items():
   
            m=str(k)
            if m=="N1":
                print("N1")
                file=open('input1.txt','r')
                for x , N1 in enumerate(file):
                    print(N1)
            if m=='N2':
                print("N2")
                file=open('input2.txt','r')
                for x , N2 in enumerate(file):
                    print(N2)
        
            if m=='N3':
                print("N3")
                file=open('input3.txt','r')
                for x , N3 in enumerate(file):
                    print(N3)
            if m=='N4':
                print("N4")
                file=open('input4.txt','r')
                for x , N4 in enumerate(file):
                    print(N4)
            else:
                print(" ")
        pos = nx.spring_layout(DG)
        nx.draw(DG,pos,node_color='r',node_size=500,alpha=1)
        plt.show()

# %% [markdown]
# ###

# %%
class Graph(object):

    def __init__(self, graph_dict=None):
        """ initializes a graph object 
            If no dictionary or None is given, 
            an empty dictionary will be used
        """
        if graph_dict == None:
            graph_dict = {}
        self.__graph_dict = graph_dict

    def vertices(self):
        """ returns the vertices of a graph """
        return list(self.__graph_dict.keys())

    def edges(self):
        """ returns the edges of a graph """
        return self.__generate_edges()

    def add_vertex(self, vertex):
        """ If the vertex "vertex" is not in 
            self.__graph_dict, a key "vertex" with an empty
            list as a value is added to the dictionary. 
            Otherwise nothing has to be done. 
        """
        if vertex not in self.__graph_dict:
            self.__graph_dict[vertex] = []

    def add_edge(self, edge): 
        """ assumes that edge is of type set, tuple or list; 
            between two vertices can be multiple edges! 
        """
        edge = set(edge)
        (vertex1, vertex2) = tuple(edge)
        if vertex1 in self.__graph_dict:
            self.__graph_dict[vertex1].append(vertex2)
        else:
            self.__graph_dict[vertex1] = [vertex2]

    def __generate_edges(self):
        """ A static method generating the edges of the 
            graph "graph". Edges are represented as sets 
            with one (a loop back to the vertex) or two 
            vertices 
        """
        edges = []
        for vertex in self.__graph_dict:
            for neighbour in self.__graph_dict[vertex]:
                if {neighbour, vertex} not in edges:
                    edges.append({vertex, neighbour})
        return edges

    def __str__(self):
        res = "vertices: "
        for k in self.__graph_dict:
            res += str(k) + " "
        res += "\nedges: "
        for edge in self.__generate_edges():
            res += str(edge) + " "
        return res


if __name__ == "__main__":

    g = { "a" : ["d"],
          "b" : ["c"],
          "c" : ["b", "c", "d", "e"],
          "d" : ["a", "c"],
          "e" : ["c"],
          "f" : []
        }


    graph = Graph(g)

    print("Vertices of graph:")
    print(graph.vertices())

    print("Edges of graph:")
    print(graph.edges())

    print("Add vertex:")
    graph.add_vertex("z")

    print("Vertices of graph:")
    print(graph.vertices())
 
    print("Add an edge:")
    graph.add_edge({"a","z"})
    
    print("Vertices of graph:")
    print(graph.vertices())

    print("Edges of graph:")
    print(graph.edges())

    print('Adding an edge {"x","y"} with new vertices:')
    graph.add_edge({"x","y"})
    print("Vertices of graph:")
    print(graph.vertices())
    print("Edges of graph:")
    print(graph.edges())
# Out:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f']
# Edges of graph:
# [{'a', 'd'}, {'c', 'b'}, {'c'}, {'c', 'd'}, {'e', 'c'}]
# Add vertex:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f', 'z']
# Add an edge:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f', 'z']
# Edges of graph:
# [{'a', 'd'}, {'a', 'z'}, {'c', 'b'}, {'c'}, {'c', 'd'}, {'e', 'c'}]
# Adding an edge {"x","y"} with new vertices:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f', 'z', 'x']
# Edges of graph:
# [{'a', 'd'}, {'a', 'z'}, {'c', 'b'}, {'c'}, {'c', 'd'}, {'e', 'c'}, {'x', 'y'}]
